# %%
import numpy as np
import pandas as pd
from bs4 import BeautifulSoup
from tensorflow import keras
import tensorflow as tf
#import requests
from urllib import request
import time

# %%
main_url = 'https://www.switchup.org'
url_berlin = 'https://www.switchup.org/rankings/best-bootcamps-berlin'
page = request.urlopen(url_berlin)
soup_berlin = BeautifulSoup(page)

# %%
soup_berlin
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# <!-- Google Tag Manager -->
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#     new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#     j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#     'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#     })(window,document,'script','dataLayer','GTM-M6MGFGN');</script>
# <!-- End Google Tag Manager -->
# <meta content="hg" name="cms"/>
# <meta content="authenticity_token" name="csrf-param"/>
# <meta content="oWFIQGMk+hAU5BZ0Dqy+g/GWdBnYk7q0HNBzxHIbFzY=" name="csrf-token"/>
# <link href="https://switch-production-herokuapp-com.global.ssl.fastly.net/assets/application-14318a431daee07cc20f001c8433139c.css" media="screen" rel="stylesheet" type="text/css"/>
# <meta content="en-us" http-equiv="content-language"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# ...

# %%
type(soup_berlin.find_all)
# Out:
# method

# %%
soup_berlin.find_all ('h3')
# Out:
# [<h3 style="margin-bottom:5px;">Best Bootcamp Highlights</h3>, <h3>
#            1.
#          <a href="/bootcamps/le-wagon" itemprop="url">Le Wagon</a>
#  </h3>, <h3>
#            2.
#          <a href="/bootcamps/ironhack" itemprop="url">Ironhack</a>
#  </h3>, <h3>
#            3.
#          <a href="/bootcamps/ubiqum-code-academy" itemprop="url">Ubiqum Code Academy</a>
#  </h3>, <h3>
#            4.
#          <a href="/bootcamps/careerfoundry" itemprop="url">CareerFoundry</a>
#  </h3>, <h3>
#            5.
#          <a href="/bootcamps/spiced-academy" itemprop="url">SPICED Academy</a>
#  </h3>, <h3>
#            6.
#          <a href="/bootcamps/wild-code-school" itemprop="url">Wild Code School</a>
#  </h3>, <h3>
#            7.
#          <a href="/bootcamps/data-science-retreat" itemprop="url">Data Science Retreat</a>
#  </h3>, <h3>
#            8.
#          <a href="/bootcamps/code-berlin" itemprop="url">CODE Berlin</a>
# ...

# %%
for item in soup_berlin.find_all('h3')
# Out:
#   File "<ipython-input-11-fd7cd23ae4a7>", line 1
#     for item in soup_berlin.find_all('h3')
#                                           ^
# SyntaxError: invalid syntax

# %%
for item in soup_berlin.find_all('h3'):
 print(item.text)
# Out:
# Best Bootcamp Highlights
#
#           1.
#         Le Wagon
#
#
#           2.
#         Ironhack
#
#
#           3.
#         Ubiqum Code Academy
#
#
#           4.
#         CareerFoundry
#
#
#           5.
#         SPICED Academy
#
#
#           6.
#         Wild Code School
#
#
#           7.
#         Data Science Retreat
#
#
#           8.
#         CODE Berlin
#
# September 18, 2018
# Featured Schools
# More Top Rankings:

# %%
for item in soup_berlin.find_all('h3'):
 print(item)
 print(item.text)
# Out:
# <h3 style="margin-bottom:5px;">Best Bootcamp Highlights</h3>
# Best Bootcamp Highlights
# <h3>
#           1.
#         <a href="/bootcamps/le-wagon" itemprop="url">Le Wagon</a>
# </h3>
#
#           1.
#         Le Wagon
#
# <h3>
#           2.
#         <a href="/bootcamps/ironhack" itemprop="url">Ironhack</a>
# </h3>
#
#           2.
#         Ironhack
#
# <h3>
#           3.
#         <a href="/bootcamps/ubiqum-code-academy" itemprop="url">Ubiqum Code Academy</a>
# </h3>
#
#           3.
#         Ubiqum Code Academy
#
# <h3>
#           4.
#         <a href="/bootcamps/careerfoundry" itemprop="url">CareerFoundry</a>
# </h3>
#
#           4.
#         CareerFoundry
#
# <h3>
#           5.
#         <a href="/bootcamps/spiced-academy" itemprop="url">SPICED Academy</a>
# </h3>
#
#           5.
#         SPICED Academy
#
# <h3>
#           6.
#         <a href="/bootcamps/wild-code-school" itemprop="url">Wild Code School</a>
# </h3>
#
#           6.
#         Wild Code School
#
# ...

# %%
for item in soup_berlin.find_all('h3'):
 print(item.a)
# Out:
# None
# <a href="/bootcamps/le-wagon" itemprop="url">Le Wagon</a>
# <a href="/bootcamps/ironhack" itemprop="url">Ironhack</a>
# <a href="/bootcamps/ubiqum-code-academy" itemprop="url">Ubiqum Code Academy</a>
# <a href="/bootcamps/careerfoundry" itemprop="url">CareerFoundry</a>
# <a href="/bootcamps/spiced-academy" itemprop="url">SPICED Academy</a>
# <a href="/bootcamps/wild-code-school" itemprop="url">Wild Code School</a>
# <a href="/bootcamps/data-science-retreat" itemprop="url">Data Science Retreat</a>
# <a href="/bootcamps/code-berlin" itemprop="url">CODE Berlin</a>
# None
# None
# None

# %%
for item in soup_berlin.find_all('h3'):
 if (item.a):
  print(item.a)
# Out:
# <a href="/bootcamps/le-wagon" itemprop="url">Le Wagon</a>
# <a href="/bootcamps/ironhack" itemprop="url">Ironhack</a>
# <a href="/bootcamps/ubiqum-code-academy" itemprop="url">Ubiqum Code Academy</a>
# <a href="/bootcamps/careerfoundry" itemprop="url">CareerFoundry</a>
# <a href="/bootcamps/spiced-academy" itemprop="url">SPICED Academy</a>
# <a href="/bootcamps/wild-code-school" itemprop="url">Wild Code School</a>
# <a href="/bootcamps/data-science-retreat" itemprop="url">Data Science Retreat</a>
# <a href="/bootcamps/code-berlin" itemprop="url">CODE Berlin</a>

# %%
for item in soup_berlin.find_all('h3'):
 if (item.a):
  print(item.a.string)
# Out:
# Le Wagon
# Ironhack
# Ubiqum Code Academy
# CareerFoundry
# SPICED Academy
# Wild Code School
# Data Science Retreat
# CODE Berlin

# %%
for item in soup_berlin.find_all('h3'):
 if (item.a):
  print(item.a.get('href'))
# Out:
# /bootcamps/le-wagon
# /bootcamps/ironhack
# /bootcamps/ubiqum-code-academy
# /bootcamps/careerfoundry
# /bootcamps/spiced-academy
# /bootcamps/wild-code-school
# /bootcamps/data-science-retreat
# /bootcamps/code-berlin

# %%
main_url = 'https://www.switchup.org'
url_berlin = 'https://www.switchup.org/bootcamps/ubiqum-code-academy'
page = request.urlopen(url_berlin)
soup = BeautifulSoup(page)

# %%
soup_berlin
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <meta content="authenticity_token" name="csrf-param"/>
# <meta content="jBASZ+k7FAJILIhElDv/t4q5lxcqyV5ee5wxyjEwSU57E2lWfmixwxH1twishxm9GMapaezwUa9iY4KCX9nvVQ==" name="csrf-token"/>
# <link href="https://www.switchup.org/bootcamps/ubiqum-code-academy" rel="canonical"/>
# <meta content="NOODP" name="robots"/>
# ...

# %%
soup_berlin.find_all ('h3')
# Out:
# [<h3>Locations</h3>,
#  <h3><page-data-prop name="bootcampName"></page-data-prop> Reviews</h3>]

# %%
for item in soup_berlin.find_all('h3'):
 print(item.text)
# Out:
# Locations
#  Reviews

# %%
for item in soup_berlin.find_all('h3'):
 print(item)
 print(item.text)
# Out:
# <h3>Locations</h3>
# Locations
# <h3><page-data-prop name="bootcampName"></page-data-prop> Reviews</h3>
#  Reviews

# %%
page = request.urlopen(url_berlin)
soup = BeautifulSoup(page)

# %%
soup
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# <!-- Google Tag Manager -->
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#     new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#     j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#     'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#     })(window,document,'script','dataLayer','GTM-M6MGFGN');</script>
# <!-- End Google Tag Manager -->
# <meta content="hg" name="cms"/>
# <meta content="authenticity_token" name="csrf-param"/>
# <meta content="7bGaR5r5RW7lsBk8jWhX0sqOEYFHzmpdoiCq9LVfHRo=" name="csrf-token"/>
# <link href="https://switch-production-herokuapp-com.global.ssl.fastly.net/assets/application-14318a431daee07cc20f001c8433139c.css" media="screen" rel="stylesheet" type="text/css"/>
# <meta content="en-us" http-equiv="content-language"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# ...

# %%
soup.table
# Out:
# <table class="course-info">
# <tbody>
# <tr>
# <th>Description</th>
# <td>
# <p>Train yourself in the skills needed to analyse large amounts of data automatically and find patterns that improve business decisions in any field of professional activity.</p>
# <p>This program is aimed ...</p>
# ...

# %%
for item in soup.table.find_all('tr'):    
 print(item)
# Out:
# <tr>
# <th>Description</th>
# <td>
# <p>Train yourself in the skills needed to analyse large amounts of data automatically and find patterns that improve business decisions in any field of professional activity.</p>
# <p>This program is aimed ...</p>
# ...

# %%
for item in soup.table.find_all('tr'):  
    if (item.th.text=="Location"):
     print(item.td)
# Out:
# <td>Berlin, Barcelona, Madrid, Amsterdam</td>

# %%
for item in soup.table.find_all('tr'):  
    if (item.th.text=="Location"):
     print(item.td.text)
# Out:
# Berlin, Barcelona, Madrid, Amsterdam

# %%
for item in soup.table.find_all('tr'):  
     print(item.td.text)
# Out:
# Train yourself in the skills needed to analyse large amounts of data automatically and find patterns that improve business decisions in any field of professional activity.
# This program is aimed ...
# Read more
#
# Data Science, Data Visualization, R Programming, Machine Learning, Statistics & Probability, AWS, Algorithms, SQL Business Intelligence
# Berlin, Barcelona, Madrid, Amsterdam
# $9,900.00
# Rolling Dates
# 20 weeks
# 15 students
# 40 hours in class/wk

# %%
table = {'Description':[],'Location':[],'Cost':[]}
for item in soup.table.find_all('tr'):
    
    if item.th.text=='Description':
        table[item.th.text].append(item.td.text)
    if item.th.text=='Location':
        table[item.th.text].append(item.td.text)
    if item.th.text=='Cost':
        table[item.th.text].append(item.td.text.split('.')[0])

# %%
df= pd.DataFrame(data=table)

# %%
df
# Out:
#                                          Description  \
# 0  \nTrain yourself in the skills needed to analy...
#
#                                Location    Cost
# 0  Berlin, Barcelona, Madrid, Amsterdam  $9,900

# %%
table = {'Description':[],'Location':[],'Cost':[]}
for item in soup.table.find_all('tr'):
    
    if item.th.text=='Description':
        table[item.th.text].append(item.td.text)
    if item.th.text=='Location':
        table[item.th.text].append(item.td.text)
    if item.th.text=='Cost':
        table[item.th.text].append(item.td.text.split('.')[0].replace('$','').replace(',',''))

# %%
df1= pd.DataFrame(data=table)

# %%
df1
# Out:
#                                          Description  \
# 0  \nTrain yourself in the skills needed to analy...
#
#                                Location  Cost
# 0  Berlin, Barcelona, Madrid, Amsterdam  9900
